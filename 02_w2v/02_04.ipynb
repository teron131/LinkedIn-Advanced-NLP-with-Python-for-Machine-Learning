# %% [markdown]
# # word2vec: How To Prep Word Vectors For Modeling

# %% [markdown]
# ### Train Our Own Model

# %%
# Read in the data, clean it, split it into train and test sets, and then train a word2vec model
import gensim
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
pd.set_option('display.max_colwidth', 100)

messages = pd.read_csv('../data/spam.csv', encoding='latin-1')
messages = messages.drop(labels = ["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis = 1)
messages.columns = ["label", "text"]


messages['text_clean'] = messages['text'].apply(lambda x: gensim.utils.simple_preprocess(x))
X_train, X_test, y_train, y_test = train_test_split(messages['text_clean'],
                                                    messages['label'], test_size=0.2)

w2v_model = gensim.models.Word2Vec(X_train, vector_size=100, window=5, min_count=2)

# %% [markdown]
# ### Prep Word Vectors

# %%
# Generate a list of words the word2vec model learned word vectors for
w2v_model.wv.index_to_key
# Out:
# ['you',
#  'to',
#  'the',
#  'and',
#  'in',
#  'is',
#  'me',
#  'my',
#  'it',
#  'for',
#  'your',
#  'call',
#  'of',
#  'have',
#  'that',
#  'on',
#  'are',
#  'now',
#  'so',
#  'can',
#  'but',
#  'not',
#  'or',
#  'at',
#  'we',
#  'get',
#  'do',
#  'if',
#  'be',
#  'ur',
#  'will',
#  'with',
#  'just',
#  'no',
#  'this',
#  'how',
#  'up',
#  'gt',
#  'lt',
#  'what',
#  'when',
#  'free',
#  'go',
#  'from',
#  'ok',
#  'all',
#  'out',
#  'll',
#  'like',
#  'know',
#  'day',
#  'got',
#  'am',
#  'good',
#  'then',
#  'there',
#  'was',
#  'only',
#  'he',
#  'come',
#  'its',
#  'love',
#  'text',
#  'send',
#  'time',
#  'want',
#  'txt',
#  'one',
#  'home',
#  'by',
#  'as',
#  'today',
#  'about',
#  'going',
#  'stop',
#  'see',
#  'she',
#  'our',
#  'da',
#  'lor',
#  'reply',
#  'sorry',
#  'need',
#  'still',
#  'don',
#  'back',
#  'dont',
#  'mobile',
#  'please',
#  'take',
#  'later',
#  'her',
#  'any',
#  'did',
#  'they',
#  'think',
#  'new',
# ...

# %%
# Generate aggregated sentence vectors based on the word vectors for each word in the sentence
w2v_vect = [np.array([w2v_model.wv[i] for i in ls if i in w2v_model.wv]) for ls in X_test]

print(len(w2v_vect), len(w2v_vect[0]))
# Out:
# 1115 30

# %%
# Why is the length of the sentence different than the length of the sentence vector?
for i, v in enumerate(w2v_vect):
    print(len(X_test.iloc[i]), len(v), len(X_test.iloc[i]) == len(v))
# Out:
# 30 30 True
# 36 36 True
# 6 5 False
# 15 10 False
# 6 6 True
# 6 6 True
# 26 21 False
# 8 8 True
# 15 15 True
# 12 12 True
# 6 5 False
# 7 7 True
# 7 6 False
# 24 24 True
# 12 12 True
# 20 20 True
# 6 6 True
# 4 4 True
# 11 10 False
# 26 19 False
# 4 4 True
# 6 6 True
# 18 17 False
# 19 13 False
# 11 9 False
# 29 29 True
# 23 18 False
# 6 6 True
# 16 12 False
# 14 12 False
# 12 8 False
# 6 6 True
# 10 9 False
# 6 4 False
# 31 29 False
# 7 7 True
# 5 3 False
# 15 14 False
# 29 25 False
# 14 14 True
# 68 67 False
# 12 5 False
# 6 6 True
# 14 12 False
# 7 7 True
# 7 7 True
# 5 4 False
# 2 2 True
# 3 3 True
# 29 24 False
# 21 20 False
# 25 25 True
# 14 11 False
# 10 10 True
# 11 8 False
# 4 4 True
# 24 21 False
# 7 7 True
# 12 12 True
# 2 0 False
# 16 15 False
# 24 22 False
# 12 12 True
# 25 21 False
# 5 5 True
# 27 26 False
# 29 29 True
# 17 17 True
# 9 9 True
# 12 11 False
# 5 5 True
# 17 13 False
# 3 3 True
# 5 5 True
# 10 10 True
# 3 2 False
# 10 9 False
# 19 17 False
# 5 4 False
# ...

# %%
# Compute sentence vectors by averaging the word vectors for the words contained in the sentence
w2v_vect_avg = []

for vect in w2v_vect:
    if len(vect)!=0:
        w2v_vect_avg.append(vect.mean(axis=0))
    else:
        w2v_vect_avg.append(np.zeros(100))

print(len(w2v_vect_avg), len(w2v_vect_avg[0]))
# Out:
# 1115 100

# %%
# Are our sentence vector lengths consistent?
for i, v in enumerate(w2v_vect_avg):
    print(len(X_test.iloc[i]), len(v))
# Out:
# 30 100
# 36 100
# 6 100
# 15 100
# 6 100
# 6 100
# 26 100
# 8 100
# 15 100
# 12 100
# 6 100
# 7 100
# 7 100
# 24 100
# 12 100
# 20 100
# 6 100
# 4 100
# 11 100
# 26 100
# 4 100
# 6 100
# 18 100
# 19 100
# 11 100
# 29 100
# 23 100
# 6 100
# 16 100
# 14 100
# 12 100
# 6 100
# 10 100
# 6 100
# 31 100
# 7 100
# 5 100
# 15 100
# 29 100
# 14 100
# 68 100
# 12 100
# 6 100
# 14 100
# 7 100
# 7 100
# 5 100
# 2 100
# 3 100
# 29 100
# 21 100
# 25 100
# 14 100
# 10 100
# 11 100
# 4 100
# 24 100
# 7 100
# 12 100
# 2 100
# 16 100
# 24 100
# 12 100
# 25 100
# 5 100
# 27 100
# 29 100
# 17 100
# 9 100
# 12 100
# 5 100
# 17 100
# 3 100
# 5 100
# 10 100
# 3 100
# 10 100
# 19 100
# 5 100
# 30 100
# 11 100
# 12 100
# 4 100
# 9 100
# 9 100
# 8 100
# 19 100
# 6 100
# 50 100
# 15 100
# 5 100
# 25 100
# 5 100
# 19 100
# 19 100
# 12 100
# 9 100
# 7 100
# 6 100
# 18 100
# 18 100
# 6 100
# 8 100
# 14 100
# 14 100
# 13 100
# 10 100
# 24 100
# 7 100
# 6 100
# 7 100
# 22 100
# 9 100
# 23 100
# 9 100
# 13 100
# ...
